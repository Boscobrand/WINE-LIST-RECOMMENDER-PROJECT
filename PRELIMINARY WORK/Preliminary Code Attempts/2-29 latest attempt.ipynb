# %%
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
import selenium.webdriver.support.ui as ui
from selenium.webdriver.support.ui import WebDriverWait
from selenium.common.exceptions import TimeoutException
import selenium.webdriver.support.expected_conditions as EC
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import NoAlertPresentException
import sys
import os
import time
import unittest, re
from bs4 import BeautifulSoup as bs

import pandas as pd


browser = webdriver.Chrome(r'C:\webdrivers\chromedriver.exe')
#browser = webdriver.chromedriver()
#driver = webdriver.Chrome(r'C:\webdrivers\chromedriver.exe')

# Tell Selenium to get the URL 
browser.get("https://www.vivino.com/explore?e=eJwdyjsKgDAURNHdTCkasZzOHYiViDxjDAETJQl-dq_Y3NNcH1kXDbwLVBW83FRlCf2w76C_tDhYwa48JTqTZcM-M0p2waZJThPFGuxcTNK48jB-849Cos4vingfEA==")

# Selenium script to scroll to the bottom, wait 3 seconds for the next batch of data to load, then continue scrolling.  It will continue to do this until the page stops loading new data.
lenOfPage = browser.execute_script("window.scrollTo(0, document.body.scrollHeight);var lenOfPage=document.body.scrollHeight;return lenOfPage;")
match=False
while(match==False):
    lastCount = lenOfPage
    time.sleep(3)
    lenOfPage = browser.execute_script("window.scrollTo(0, document.body.scrollHeight);var lenOfPage=document.body.scrollHeight;return lenOfPage;")
    if lastCount==lenOfPage:
        match=True

# Now that the page is fully scrolled, grab the source code.
# changed driver to browser in code below
#file_A=browser.find_element_by_class_name('explorerPage__results--3wqLw')
#print(file_A.text)

#pos= 0
#df = pd.DataFrame(columns=['winery','wine','location','rating','price'])

for ol in browser.find_elements_by_class_name("explorerPage__results--3wqLw"):
    
    winery = browser.find_elements_by_class_name("vintageTitle__winery--2YoIr").get_attribute("innerHTML")
    wine = browser.find_elements_by_class_name("vintageTitle__wine--U7t9G").get_attribute("innerHTML")
    location = browser.find_elements_by_class_name("vintageLocation__vintageLocation--1DF0p").get_attribute("innerHTML")
    rating = browser.find_elements_by_class_name("vivinoRatingWide__averageValue--1zL_5").get_attribute("innerHTML")
#   price = browser.find_elements_by_id
    
    
    # make one empty list for each column    
#    winery_list, wine_list, loc_list, rating_list, price_list = [], [], [], [], []
            
#    for a in winery:
#       winery_list.append(a)
#    for b in wine:
#        wine_list.append(b)
#    for c in location:
#        loc_list.append(c)
#    for d in rating:
#        rating_list.append(d)
        
    #price_list.append(browser.find_elements_by_id('<button aria-label="Add to cart" class="button__button--247vZ button__themeAddToCart--3i8L2 button__sizeDefault--3HuoB addToCartButton__addToCartButton--qZv9F explorerCard__button--3HZ-g"')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-122c14c99004> in <module>
#      46 for ol in browser.find_elements_by_class_name("explorerPage__results--3wqLw"):
#      47
# ---> 48     winery = browser.find_elements_by_class_name("vintageTitle__winery--2YoIr").get_attribute("innerHTML")
#      49     wine = browser.find_elements_by_class_name("vintageTitle__wine--U7t9G").get_attribute("innerHTML")
#      50     location = browser.find_elements_by_class_name("vintageLocation__vintageLocation--1DF0p").get_attribute("innerHTML")
#
# AttributeError: 'list' object has no attribute 'get_attribute'

# %%
winery
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="d8727548c3ffe2d21089390a6915dcc1", element="74d37254-f575-445d-a8f2-31d249a623a3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d8727548c3ffe2d21089390a6915dcc1", element="f1de1183-a36a-4755-ab3a-c561480851ae")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d8727548c3ffe2d21089390a6915dcc1", element="4fc74497-8be8-44c9-9777-66d87d22a91c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d8727548c3ffe2d21089390a6915dcc1", element="62556a3f-ff6b-4e85-8630-6100dfcf24e5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d8727548c3ffe2d21089390a6915dcc1", element="450ff12e-204a-46be-b1f4-43b4ab657626")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d8727548c3ffe2d21089390a6915dcc1", element="76e77a0c-7b77-4e2c-9e51-556deb4eb3e9")>,
# ...

# %%
wine
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="d8727548c3ffe2d21089390a6915dcc1", element="1cc53b77-424d-4c06-8dd7-fc4eb6698aec")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d8727548c3ffe2d21089390a6915dcc1", element="235249a5-02f1-4677-9946-d207de3adb16")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d8727548c3ffe2d21089390a6915dcc1", element="74d68a97-36d5-4f01-b7bd-fe53d22ff76d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d8727548c3ffe2d21089390a6915dcc1", element="4f2e1a92-4819-4e3d-a3b8-1799e6aba5c0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d8727548c3ffe2d21089390a6915dcc1", element="78412083-9fb3-4f88-870f-315ff2e96e4d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d8727548c3ffe2d21089390a6915dcc1", element="82d679ad-f0c6-4bac-b799-c67d050a9ae9")>,
# ...

# %%
location
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="d8727548c3ffe2d21089390a6915dcc1", element="c7ed03b2-9d47-4078-81a2-aa8a90c714d2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d8727548c3ffe2d21089390a6915dcc1", element="ea58e564-5ccf-4196-9d02-3958a841cbc7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d8727548c3ffe2d21089390a6915dcc1", element="d8c14f89-910f-45b7-a79d-973690dd87c2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d8727548c3ffe2d21089390a6915dcc1", element="cc2f7c13-3941-448f-bbc0-84bb16a0a0c0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d8727548c3ffe2d21089390a6915dcc1", element="fb96883f-1821-41be-af62-465cbf0d4d7c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d8727548c3ffe2d21089390a6915dcc1", element="c953e6c2-4541-4335-8504-fb6c6de79bb3")>,
# ...

# %%
rating
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="d8727548c3ffe2d21089390a6915dcc1", element="56b91f38-8b22-4487-a80b-1fcbf357fcde")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d8727548c3ffe2d21089390a6915dcc1", element="98ece287-07ba-4825-a1eb-69e5da60669b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d8727548c3ffe2d21089390a6915dcc1", element="86735d44-143b-464e-8a39-aa19cab8768d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d8727548c3ffe2d21089390a6915dcc1", element="e9d63fbf-3047-4a78-a855-54d3b5967a41")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d8727548c3ffe2d21089390a6915dcc1", element="c7334aa0-0f3e-436a-8ed5-e9ca14e71664")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d8727548c3ffe2d21089390a6915dcc1", element="c4cb0c6f-bafe-4a30-9375-21012aa69264")>,
# ...

# %%
df = ({
    'winery': winery_list,
    'wine': wine_list,
    'location': loc_list,
    'rating': rating_list,
    #'price': price_list,
})

data=pd.DataFrame(df)
                                                    
data.head()
# Out:
#   winery wine location rating
# 0     []   []       []     []
