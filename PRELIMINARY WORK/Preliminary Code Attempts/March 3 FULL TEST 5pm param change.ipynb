# %%
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
import selenium.webdriver.support.ui as ui
from selenium.webdriver.support.ui import WebDriverWait
from selenium.common.exceptions import TimeoutException
import selenium.webdriver.support.expected_conditions as EC
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import NoAlertPresentException
import sys
import os
import time
import unittest, re
from bs4 import BeautifulSoup as bs

import pandas as pd

browser = webdriver.Chrome(r'C:\webdrivers\chromedriver.exe')
#browser = webdriver.chromedriver()
#driver = webdriver.Chrome(r'C:\webdrivers\chromedriver.exe')


# https://help.crossbrowsertesting.com/selenium-testing/getting-started/python/

#dictionary off of chromedriver.exe




# Tell Selenium to get the URL 
browser.get("https://www.vivino.com/explore?e=eJzLLbI11jNVy83MszUCUokVtqYGBmrJlbahwWrJQMJFrcDWUC09zbYssSgztSQxRy0_ybYosSQzL704PrEstSgxPVUt3zYltThZrbwkOhaoGEwZQSgTCGUOoYyhciZqxbbJJQCbVSgz")


# Selenium script to scroll to the bottom, wait 3 seconds for the next batch of data to load, then continue scrolling.  It will continue to do this until the page stops loading new data.
lenOfPage = browser.execute_script("window.scrollTo(0, document.body.scrollHeight);var lenOfPage=document.body.scrollHeight;return lenOfPage;")
match=False
while(match==False):
    lastCount = lenOfPage
    time.sleep(3)
    lenOfPage = browser.execute_script("window.scrollTo(0, document.body.scrollHeight);var lenOfPage=document.body.scrollHeight;return lenOfPage;")
    if lastCount==lenOfPage:
        match=True

# Now that the page is fully scrolled, grab the source code.
# changed driver to browser in code below
#file_A=browser.find_element_by_class_name('explorerPage__results--3wqLw')
#print(file_A.text)

#pos= 0
#df = pd.DataFrame(columns=['winery','wine','location','rating','price'])



#create an empty list to hold text for each column, which we will translate to dataframe columns later:
winery_list, wine_list, loc_list, rating_list, price_list = [], [], [], [], []

#have selenium access the results page:
for ol in browser.find_elements_by_class_name("explorerPage__results--3wqLw"):

#Tell selenium what elements to find and store them in their own separate lists:    
    winery = browser.find_elements_by_class_name("vintageTitle__winery--2YoIr")
    wine = browser.find_elements_by_class_name("vintageTitle__wine--U7t9G")
    location = browser.find_elements_by_class_name("vintageLocation__vintageLocation--1DF0p")
    rating = browser.find_elements_by_class_name("vivinoRatingWide__averageValue--1zL_5")
    price = browser.find_elements_by_class_name("button__button--247vZ")
    
    
    
     #//*[@id="explore-page-app"]/div/div/div[2]/div[2]/div[1]/div[1]/div[2]/div[2]/button/span/input[@class=explorerCard_button--3HZ-g]
    
    #<button aria-label="Add to cart" class="button__themeAddToCart--3i8L2 button__sizeDefault--3HuoB addToCartButton__addToCartButton--qZv9F explorerCard__button--3HZ-g" type="button"><span class="">$499.99</span></button>
    
    #<span class="">$499.99</span>
    #//*[@id="explore-page-app"]/div/div/div[2]/div[2]/div[1]/div[1]/div[2]/div[2]/button
    #//*[@id="explore-page-app"]/div/div/div[2]/div[2]/div[1]/div[1]/div[2]/div[2]/button
    # "button__button--247vZ button__themeAddToCart--3i8L2 button__sizeDefault--3HuoB addToCartButton__addToCartButton--qZv9F explorerCard__button--3HZ-g"
    # (.//span[@class = "button"])
    # xpath('//span[@class="price"]')
    #class_name("button__button--247vZ")
    #type="button"><span class="">$499.99</span></button>
    #<span class="">$499.99</span>
    
    
#this loop needs to iterate through and print each instance
    num_winery_page_items = len(winery)
    for i in range (num_winery_page_items):
        winery_list.append(winery[i].text)
        
    num_wine_page_items = len(wine)
    for i in range (num_wine_page_items):
        wine_list.append(wine[i].text)
    
    num_location_page_items = len(location)
    for i in range (num_location_page_items):
        loc_list.append(location[i].text)
        
    num_rating_page_items = len(rating)
    for i in range (num_rating_page_items):
        rating_list.append(rating[i].text)
        
    num_price_page_items = len(price)
    for i in range (num_price_page_items):
        price_list.append(price[i].text)

# %%
winery
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="995be8ef95aa6b3c4c820714f1ce118f", element="4c98b502-2297-4e9f-ab17-8de56fe1960b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="995be8ef95aa6b3c4c820714f1ce118f", element="d0309a75-c366-42cb-83b9-8928c10d7050")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="995be8ef95aa6b3c4c820714f1ce118f", element="ca4c79ca-38e6-4d30-991d-55fd723488f3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="995be8ef95aa6b3c4c820714f1ce118f", element="ebecd770-8742-4625-b16e-30f755f4ed25")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="995be8ef95aa6b3c4c820714f1ce118f", element="3fae2ecf-8b3c-46b9-8908-0683623c073c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="995be8ef95aa6b3c4c820714f1ce118f", element="33068152-05b3-48b7-aee4-5049273d7693")>,
# ...

# %%
winery_list
# Out:
# ['Toro Albalá',
#  'Hundred Acre',
#  'Colgin',
#  'Château Haut-Brion',
#  "Château d'Yquem",
#  'Viña Cobos',
#  'ZD Wines',
#  "W. & J. Graham's",
#  'Catena Zapata',
#  'Domaine de La Romanée-Conti',
#  'Ovid',
#  'Domaine de La Romanée-Conti',
#  "Château d'Yquem",
#  'Hundred Acre',
#  'Screaming Eagle',
#  'Darioush',
#  'Château Tertre Roteboeuf',
#  'Bevan Cellars',
#  'Vega Sicilia',
#  'Viña Cobos',
#  'Pine Ridge',
#  'Dal Forno Romano',
#  'Domaine de La Romanée-Conti',
#  'Hundred Acre',
#  'Screaming Eagle',
#  'Domaine de La Romanée-Conti',
#  'Bollinger',
#  'Ovid',
#  'Abreu',
#  'Masseto',
#  'Purlieu',
#  'Bodegas El Nido',
#  'Billecart-Salmon',
#  'Royal Tokaji',
#  'Château Pavie',
#  'Pulido-Walker',
#  'Álvaro Palacios',
#  'Domaine de La Romanée-Conti',
#  'Cade',
#  'Domaine de La Romanée-Conti',
#  'Schrader',
#  'Joseph Drouhin',
#  'Kapcsandy',
#  'Hestan Vineyards',
#  "Château d'Yquem",
#  'Abreu',
#  'Dom Pérignon',
#  'Fairchild Estate',
# ...

# %%
wine
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="995be8ef95aa6b3c4c820714f1ce118f", element="dbc4822b-8aa7-47e8-9b5b-16c5d3bdf33d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="995be8ef95aa6b3c4c820714f1ce118f", element="f55d4cf0-055b-483f-8e6b-b47595613bcc")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="995be8ef95aa6b3c4c820714f1ce118f", element="e3fde627-a8dc-4e92-94f5-24611e2bb6d1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="995be8ef95aa6b3c4c820714f1ce118f", element="03e40bd2-fd47-41f5-bb9a-a3d61606d19f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="995be8ef95aa6b3c4c820714f1ce118f", element="79f0e3ff-93f3-46ad-a789-51869c1d17e7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="995be8ef95aa6b3c4c820714f1ce118f", element="ed986e6a-4207-42e3-9615-56d59eee09f8")>,
# ...

# %%
wine_list
# Out:
# ['Don PX Convento Selección 1946',
#  'Kayli Morgan Vineyard Cabernet Sauvignon 2015',
#  'IX Estate Red 2016',
#  'Pessac-Léognan (Premier Grand Cru Classé) 1961',
#  'Sauternes 2001',
#  'Cobos Marchiori Vineyard Malbec 2015',
#  'Abacus Cabernet Sauvignon N.V.',
#  'Single Harvest Tawny Port 1972',
#  'Adrianna Vineyard River Stones Malbec 2015',
#  'Grands-Échezeaux Grand Cru 2014',
#  'Red Blend 2012',
#  'La Tâche Grand Cru 2014',
#  'Sauternes 1990',
#  'Kayli Morgan Vineyard Cabernet Sauvignon 2014',
#  'Cabernet Sauvignon 2005',
#  'Darius II Cabernet Sauvignon 2016',
#  'Saint-Émilion Grand Cru 2014',
#  'Sugarloaf Mountain Vineyard Proprietary Red 2013',
#  'Unico Reserva Especial Edición 2019',
#  'Cobos Chañares Vineyard Malbec 2016',
#  'Fortis Cabernet Sauvignon 2014',
#  'Amarone della Valpolicella Monte Lodoletta 1997',
#  'Richebourg Grand Cru 2003',
#  'Wraith Cabernet Sauvignon 2013',
#  'Cabernet Sauvignon 2003',
# ...

# %%
location
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="995be8ef95aa6b3c4c820714f1ce118f", element="682a46e5-a482-4607-8773-d472c32545ca")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="995be8ef95aa6b3c4c820714f1ce118f", element="aa0839ef-a87c-4a45-84d1-df8ec545e2d1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="995be8ef95aa6b3c4c820714f1ce118f", element="b9436072-8a11-486a-8453-a31522185d3a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="995be8ef95aa6b3c4c820714f1ce118f", element="c043ee1f-414d-4593-afd4-f1e9ec15110d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="995be8ef95aa6b3c4c820714f1ce118f", element="a867c89e-b9bc-425f-b3f3-e8faee288db8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="995be8ef95aa6b3c4c820714f1ce118f", element="842d070a-ef95-41ae-a94e-87704c5f624b")>,
# ...

# %%
loc_list
# Out:
# ['Spain\n·\nMontilla-Moriles',
#  'United States\n·\nNapa Valley',
#  'United States\n·\nNapa Valley',
#  'France\n·\nPessac-Léognan',
#  'France\n·\nSauternes',
#  'Argentina\n·\nMendoza',
#  'United States\n·\nNapa Valley',
#  'Portugal\n·\nPorto',
#  'Argentina\n·\nMendoza',
#  'France\n·\nGrands-Échezeaux Grand Cru',
#  'United States\n·\nNapa Valley',
#  'France\n·\nLa Tâche Grand Cru',
#  'France\n·\nSauternes',
#  'United States\n·\nNapa Valley',
#  'United States\n·\nOakville',
#  'United States\n·\nNapa Valley',
#  'France\n·\nSaint-Émilion Grand Cru',
#  'United States\n·\nNapa Valley',
#  'Spain\n·\nRibera del Duero',
#  'Argentina\n·\nTunuyán',
#  'United States\n·\nNapa Valley',
#  'Italy\n·\nAmarone della Valpolicella',
#  'France\n·\nRichebourg Grand Cru',
#  'United States\n·\nNapa Valley',
#  'United States\n·\nOakville',
#  'France\n·\nRomanée-Saint-Vivant Grand Cru',
#  'France\n·\nChampagne',
#  'United States\n·\nNapa Valley',
#  'United States\n·\nNapa Valley',
# ...

# %%
rating
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="995be8ef95aa6b3c4c820714f1ce118f", element="4c29c82a-1b2f-48e1-bd1f-2caffc729d4c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="995be8ef95aa6b3c4c820714f1ce118f", element="2cc7fe27-51f1-4660-9d09-613bea8203ea")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="995be8ef95aa6b3c4c820714f1ce118f", element="e4f4ba66-b145-4fa9-97c4-5c34a5b1de96")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="995be8ef95aa6b3c4c820714f1ce118f", element="26eb5a76-b57c-4035-933a-dc74a6d78edb")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="995be8ef95aa6b3c4c820714f1ce118f", element="517b9555-0b6b-4c94-b90a-1aa607d898e5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="995be8ef95aa6b3c4c820714f1ce118f", element="ba70639a-3bfc-4a2c-b0c6-e47a6fd5fd8c")>,
# ...

# %%
rating_list
# Out:
# ['4.9',
#  '4.9',
#  '4.9',
#  '4.8',
#  '4.8',
#  '4.8',
#  '4.8',
#  '4.8',
#  '4.8',
#  '4.8',
#  '4.8',
#  '4.8',
#  '4.8',
#  '4.8',
#  '4.8',
#  '4.8',
#  '4.8',
#  '4.8',
#  '4.8',
#  '4.8',
#  '4.8',
#  '4.8',
#  '4.8',
#  '4.8',
#  '4.8',
#  '4.8',
#  '4.8',
#  '4.8',
#  '4.8',
#  '4.8',
#  '4.8',
#  '4.8',
#  '4.8',
#  '4.8',
#  '4.8',
#  '4.8',
#  '4.8',
#  '4.8',
#  '4.8',
#  '4.8',
#  '4.8',
#  '4.8',
#  '4.8',
#  '4.8',
#  '4.8',
#  '4.8',
#  '4.8',
#  '4.8',
#  '4.8',
#  '4.8',
#  '4.8',
#  '4.8',
#  '4.8',
#  '4.8',
#  '4.8',
#  '4.8',
#  '4.8',
#  '4.8',
#  '4.8',
#  '4.8',
#  '4.8',
#  '4.8',
#  '4.8',
#  '4.8',
#  '4.8',
#  '4.8',
#  '4.7',
#  '4.7',
#  '4.7',
#  '4.7',
#  '4.7',
#  '4.7',
#  '4.7',
#  '4.7',
#  '4.7',
#  '4.7',
#  '4.7',
#  '4.7',
#  '4.7',
#  '4.7',
#  '4.7',
#  '4.7',
#  '4.7',
#  '4.7',
#  '4.7',
#  '4.7',
#  '4.7',
#  '4.7',
#  '4.7',
#  '4.7',
#  '4.7',
#  '4.7',
#  '4.7',
#  '4.7',
#  '4.7',
#  '4.7',
#  '4.7',
#  '4.7',
#  '4.7',
#  '4.7',
# ...

# %%
price
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="995be8ef95aa6b3c4c820714f1ce118f", element="9a695f22-b651-4bc7-aa73-baac92cd476d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="995be8ef95aa6b3c4c820714f1ce118f", element="55930e06-2ab3-42e2-80c3-0cc71395aff3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="995be8ef95aa6b3c4c820714f1ce118f", element="286226fb-c1c5-483c-a94c-aaa6da2c48e2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="995be8ef95aa6b3c4c820714f1ce118f", element="d1a18246-9e77-44e2-a2cd-fee1cfe231e8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="995be8ef95aa6b3c4c820714f1ce118f", element="54aa8d2c-7b5e-497f-a700-bcda4ffae880")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="995be8ef95aa6b3c4c820714f1ce118f", element="7f32e832-7222-4566-9a71-dedc33d93d85")>,
# ...

# %%
price_list
# Out:
# ['$307.98',
#  '$499.99',
#  '$799.99',
#  '$2500',
#  '$799.99',
#  '$209.99',
#  '$749.99',
#  '$399.99',
#  '$149.99',
#  '$2499.99',
#  '$399.99',
#  '$4399.99',
#  '$449.99',
#  '$749.99',
#  '$4199.99',
#  '$324.99',
#  '$183.99',
#  '$299.99',
#  '$699.99',
#  '$335.99',
#  '$219.99',
#  '$1000',
#  '$3499.99',
#  '$699.99',
#  '$3999.99',
#  '$3499.99',
#  '$1271.99',
#  '$345',
#  '$599.99',
#  '$867.99',
#  '$186.98',
#  '$149.99',
#  '$549.99',
#  '$999.99',
#  '$676.99',
#  '$179.99',
#  '$1199.99',
#  '$21999.99',
#  '$234.99',
#  '$9999.99',
#  '$419.99',
#  '$594.99',
#  '$639.99',
#  '$141.95',
#  '$365',
#  '$599',
#  '$4499.99',
#  '$199.99',
#  '$9500',
#  '$499.99',
#  '$519.99',
#  '$350',
#  '$519.99',
#  '$287.99',
#  '$911.99',
#  '$599.99',
#  '$489',
#  '$395.99',
#  '$349.99',
#  '$2499.99',
#  '$199.99',
#  '$199.99',
#  '$279.99',
#  '$75.99',
#  '$212.99',
#  '$6199.99',
#  '$417.99',
#  '$849.99',
#  '$399',
#  '$445',
#  '$299.99',
#  '$199.99',
# ...

# %%
# set up dictionary to align lists of captured texts with dataframe column names
df = ({
    'winery': winery_list,
    'wine': wine_list,
    'location': loc_list,
    'rating': rating_list,
    'price': price_list,
})

data=pd.DataFrame(df)
                                                    
data.head()
# Out:
#                winery                                            wine  \
# 0         Toro Albalá                  Don PX Convento Selección 1946
# 1        Hundred Acre   Kayli Morgan Vineyard Cabernet Sauvignon 2015
# 2              Colgin                              IX Estate Red 2016
# 3  Château Haut-Brion  Pessac-Léognan (Premier Grand Cru Classé) 1961
# 4     Château d'Yquem                                  Sauternes 2001
#
#                         location rating    price
# 0     Spain\n·\nMontilla-Moriles    4.9  $307.98
# 1  United States\n·\nNapa Valley    4.9  $499.99
# 2  United States\n·\nNapa Valley    4.9  $799.99
# 3      France\n·\nPessac-Léognan    4.8    $2500
# 4           France\n·\nSauternes    4.8  $799.99

# %%
data.shape
# Out:
# (2475, 5)

# %%
data.head(20)
# Out:
#                          winery  \
# 0                   Toro Albalá
# 1                  Hundred Acre
# 2                        Colgin
# 3            Château Haut-Brion
# 4               Château d'Yquem
# 5                    Viña Cobos
# 6                      ZD Wines
# 7              W. & J. Graham's
# 8                 Catena Zapata
# 9   Domaine de La Romanée-Conti
# 10                         Ovid
# 11  Domaine de La Romanée-Conti
# 12              Château d'Yquem
# 13                 Hundred Acre
# 14              Screaming Eagle
# 15                     Darioush
# 16     Château Tertre Roteboeuf
# 17                Bevan Cellars
# 18                 Vega Sicilia
# 19                   Viña Cobos
#
#                                                 wine  \
# 0                     Don PX Convento Selección 1946
# 1      Kayli Morgan Vineyard Cabernet Sauvignon 2015
# 2                                 IX Estate Red 2016
# 3     Pessac-Léognan (Premier Grand Cru Classé) 1961
# ...

# %%
data.to_csv('wine_file_145pm.csv')
