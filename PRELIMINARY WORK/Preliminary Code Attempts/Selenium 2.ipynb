# %%
#Importing packages
from selenium import webdriver
import pandas as pd

# %%
driver = webdriver.Chrome(r'C:\webdrivers\chromedriver.exe')

# %%
driver.get('https://www.vivino.com/explore?e=eJwdyjsKgDAURNHdTCkasZzOHYiViDxjDAETJQl-dq_Y3NNcH1kXDbwLVBW83FRlCf2w76C_tDhYwa48JTqTZcM-M0p2waZJThPFGuxcTNK48jB-849Cos4vingfEA==')

# %%
driver.find_element_by_class_name('explorerPage__results--3wqLw')
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="e922d9319583d738d200f48b91516ca9", element="794a69aa-04ee-448b-b081-91401f128179")>

# %%
file_1=driver.find_element_by_class_name('explorerPage__results--3wqLw')
print(file_1.text)
# Out:
# Monteviejo
# Lindaflor La Violeta Malbec 2010
# Argentina
# ·
# Uco Valley
# 4.8
# 217 ratings
# $129.99
# “The best Malbec I ever tried. Black cherries and strawberries in splendid way, round with long finish, absolute delight! ”
# Miroslav
# Catena Zapata
# Adrianna Vineyard River Stones Malbec 2015
# Argentina
# ·
# Mendoza
# 4.8
# 190 ratings
# $149.99
# “What a smooth and beautiful wine. leather oak blueberry tobacco. It does show a light finish and an elegant aroma. It worths all those 5 stars. ”
# Billy Maior
# Quinta do Vale Meão
# Douro 2017
# Portugal
# ·
# Douro
# 4.8
# 120 ratings
# $99
# Château Tertre Roteboeuf
# Saint-Émilion Grand Cru 2014
# France
# ·
# Saint-Émilion Grand Cru
# 4.8
# 98 ratings
# $183.99
# Purlieu
# Georges III Vineyard Cabernet Sauvignon N.V.
# United States
# ·
# Napa Valley
# 4.8
# 52 ratings
# $186.98
# Pulido-Walker
# Panek Vineyard Cabernet Sauvignon 2012
# United States
# ·
# Napa Valley
# 4.8
# 48 ratings
# $179.99
# Fairchild Estate
# ...

# %%
file_1.text.split('\n')
# Out:
# ['Monteviejo',
#  'Lindaflor La Violeta Malbec 2010',
#  'Argentina',
#  '·',
#  'Uco Valley',
#  '4.8',
#  '217 ratings',
#  '$129.99',
#  '“The best Malbec I ever tried. Black cherries and strawberries in splendid way, round with long finish, absolute delight! ”',
#  'Miroslav',
#  'Catena Zapata',
#  'Adrianna Vineyard River Stones Malbec 2015',
#  'Argentina',
#  '·',
#  'Mendoza',
#  '4.8',
#  '190 ratings',
#  '$149.99',
#  '“What a smooth and beautiful wine. leather oak blueberry tobacco. It does show a light finish and an elegant aroma. It worths all those 5 stars. ”',
#  'Billy Maior',
#  'Quinta do Vale Meão',
#  'Douro 2017',
#  'Portugal',
#  '·',
#  'Douro',
#  '4.8',
#  '120 ratings',
#  '$99',
#  'Among top 1% of all wines in the world',
#  'Château Tertre Roteboeuf',
#  'Saint-Émilion Grand Cru 2014',
#  'France',
#  '·',
#  'Saint-Émilion Grand Cru',
#  '4.8',
#  '98 ratings',
#  '$183.99',
#  'Purlieu',
#  'Georges III Vineyard Cabernet Sauvignon N.V.',
# ...

# %%
#userid_element = driver.find_elements_by_xpath('')[0]
#userid = userid_element.text


#//*[@id="explore-page-app"]/div/div/div[2]/div[1]/div[1]/div[2]/div[1]/a/span[2]
#//a/*<div class="explorerCard__titleColumn--28kWX"><div class="vintageTitle__vintageTitle--2iCdc"><a class="anchor__anchor--2QZvA" href="/monteviejo-lindaflor-la-violeta-malbec/w/1556378?year=2010&amp;price_id=17622349" target="_blank"><span class="vintageTitle__winery--2YoIr">Monteviejo</span><span class="vintageTitle__wine--U7t9G">Lindaflor La Violeta Malbec 2010</span></a><div class="vintageLocation__vintageLocation--1DF0p"><a class="anchor__anchor--2QZvA vintageLocation__anchor--T7J3k" href="/wine-countries/argentina"><i title="Argentina" class="countryFlag__outer--2Qh6s vintageLocation__countryFlag--1HbXr countryFlag__small--1GZwg" style="background-image: url(&quot;https://images.vivino.com/web/flags/ar.svg&quot;);"></i></a><a class="anchor__anchor--2QZvA vintageLocation__anchor--T7J3k" href="/wine-countries/argentina">Argentina</a><span>·</span><a class="anchor__anchor--2QZvA vintageLocation__anchor--T7J3k" href="/wine-regions/valle-de-uco">Uco Valley</a></div></div><div class="explorerCard__ratingAndPrice--2dw-T"><div class="explorerCard__rating--g-Wi2"><div class="vivinoRatingWide__vivinoRatingWide--1anqU vivinoRatingWide__sizeMedium--2RWrK"><div class="vivinoRatingWide__averageValue--1zL_5">4.8</div><div class="vivinoRatingWide__starsAndReviews--rllAo"><div class="rating__rating--ZZb_x rating__vivino--1vGCy"><i class="rating__icon--2T9_0 rating__icon100--2vw_3" style="height: 12px; width: 12px;"></i><i class="rating__icon--2T9_0 rating__icon100--2vw_3" style="height: 12px; width: 12px;"></i><i class="rating__icon--2T9_0 rating__icon100--2vw_3" style="height: 12px; width: 12px;"></i><i class="rating__icon--2T9_0 rating__icon100--2vw_3" style="height: 12px; width: 12px;"></i><i class="rating__icon--2T9_0 rating__icon80--3K1U0" style="height: 12px; width: 12px;"></i></div><div class="vivinoRatingWide__basedOn--s6y0t">217 ratings</div></div></div></div><button aria-label="Add to cart" class="button__button--247vZ button__themeAddToCart--3i8L2 button__sizeDefault--3HuoB addToCartButton__addToCartButton--qZv9F explorerCard__button--3HZ-g" type="button"><span class="">$129.99</span></button></div></div>
#//*[@id="explore-page-app"]/div/div/div[2]/div[2]/div[1]/div[1]/div[2]/div[1]/a/span[2]
#<span class="vintageTitle__wine--U7t9G">Lindaflor La Violeta Malbec 2010</span>
#<a class="anchor__anchor--2QZvA" href="/monteviejo-lindaflor-la-violeta-malbec/w/1556378?year=2010&amp;price_id=17622349" target="_blank"><span class="vintageTitle__winery--2YoIr">Monteviejo</span><span class="vintageTitle__wine--U7t9G">Lindaflor La Violeta Malbec 2010</span></a>
#<div class="explorerCard__titleColumn--28kWX"><div class="vintageTitle__vintageTitle--2iCdc"><a class="anchor__anchor--2QZvA" href="/monteviejo-lindaflor-la-violeta-malbec/w/1556378?year=2010&amp;price_id=17622349" target="_blank"><span class="vintageTitle__winery--2YoIr">Monteviejo</span><span class="vintageTitle__wine--U7t9G">Lindaflor La Violeta Malbec 2010</span></a><div class="vintageLocation__vintageLocation--1DF0p"><a class="anchor__anchor--2QZvA vintageLocation__anchor--T7J3k" href="/wine-countries/argentina"><i title="Argentina" class="countryFlag__outer--2Qh6s vintageLocation__countryFlag--1HbXr countryFlag__small--1GZwg" style="background-image: url(&quot;https://images.vivino.com/web/flags/ar.svg&quot;);"></i></a><a class="anchor__anchor--2QZvA vintageLocation__anchor--T7J3k" href="/wine-countries/argentina">Argentina</a><span>·</span><a class="anchor__anchor--2QZvA vintageLocation__anchor--T7J3k" href="/wine-regions/valle-de-uco">Uco Valley</a></div></div><div class="explorerCard__ratingAndPrice--2dw-T"><div class="explorerCard__rating--g-Wi2"><div class="vivinoRatingWide__vivinoRatingWide--1anqU vivinoRatingWide__sizeMedium--2RWrK"><div class="vivinoRatingWide__averageValue--1zL_5">4.8</div><div class="vivinoRatingWide__starsAndReviews--rllAo"><div class="rating__rating--ZZb_x rating__vivino--1vGCy"><i class="rating__icon--2T9_0 rating__icon100--2vw_3" style="height: 12px; width: 12px;"></i><i class="rating__icon--2T9_0 rating__icon100--2vw_3" style="height: 12px; width: 12px;"></i><i class="rating__icon--2T9_0 rating__icon100--2vw_3" style="height: 12px; width: 12px;"></i><i class="rating__icon--2T9_0 rating__icon100--2vw_3" style="height: 12px; width: 12px;"></i><i class="rating__icon--2T9_0 rating__icon80--3K1U0" style="height: 12px; width: 12px;"></i></div><div class="vivinoRatingWide__basedOn--s6y0t">217 ratings</div></div></div></div><button aria-label="Add to cart" class="button__button--247vZ button__themeAddToCart--3i8L2 button__sizeDefault--3HuoB addToCartButton__addToCartButton--qZv9F explorerCard__button--3HZ-g" type="button"><span class="">$129.99</span></button></div></div>
