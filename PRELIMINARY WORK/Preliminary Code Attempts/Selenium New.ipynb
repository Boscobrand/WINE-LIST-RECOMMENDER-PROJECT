# %%
#Importing packages

import pandas as pd

import selenium
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
import selenium.webdriver.support.ui as ui
from selenium.webdriver.support.ui import WebDriverWait
from selenium.common.exceptions import TimeoutException
from selenium.webdriver.common.by import By
import selenium.webdriver.support.expected_conditions as EC
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import NoAlertPresentException
import sys
import os
import time
import unittest, re

# %%
driver = webdriver.Chrome(r'C:\webdrivers\chromedriver.exe')

# %%
driver.get('https://www.vivino.com/explore?e=eJwdyjsKgDAURNHdTCkasZzOHYiViDxjDAETJQl-dq_Y3NNcH1kXDbwLVBW83FRlCf2w76C_tDhYwa48JTqTZcM-M0p2waZJThPFGuxcTNK48jB-849Cos4vingfEA==')

# %%
driver.find_element_by_class_name('explorerPage__results--3wqLw')
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="629a667f7d7367d280347439e8bb816c", element="ff5b65bb-0e4e-48e0-b7ae-6f04e28d5d61")>

# %%
file_A=driver.find_element_by_class_name('explorerPage__results--3wqLw')
print(file_A.text)
# Out:
# Monteviejo
# Lindaflor La Violeta Malbec 2010
# Argentina
# ·
# Uco Valley
# 4.8
# 216 ratings
# $129.99
# “The best Malbec I ever tried. Black cherries and strawberries in splendid way, round with long finish, absolute delight! ”
# Miroslav
# Catena Zapata
# Adrianna Vineyard River Stones Malbec 2015
# Argentina
# ·
# Mendoza
# 4.8
# 192 ratings
# $149.99
# “I don’t think I can get tired of preaching about this exceptional Malbec Unique characteristics and personality on this wine ”
# Cello
# Quinta do Vale Meão
# Douro 2017
# Portugal
# ·
# Douro
# 4.8
# 161 ratings
# $99
# Château Tertre Roteboeuf
# Saint-Émilion Grand Cru 2014
# France
# ·
# Saint-Émilion Grand Cru
# 4.8
# 98 ratings
# $183.99
# Purlieu
# Georges III Vineyard Cabernet Sauvignon N.V.
# United States
# ·
# Napa Valley
# 4.8
# 52 ratings
# $186.98
# Pulido-Walker
# Panek Vineyard Cabernet Sauvignon 2012
# United States
# ·
# Napa Valley
# 4.8
# 48 ratings
# $179.99
# Bodegas El Nido
# El Nido 2017
# Spain
# ·
# Jumilla
# 4.8
# 47 ratings
# $149.99
# Fairchild Estate
# G.III Cabernet Sauvignon 2010
# United States
# ·
# Napa Valley
# 4.8
# 38 ratings
# $199.99
# Aubert
# Chardonnay Larry Hyde & Sons 2017
# United States
# ·
# Los Carneros
# 4.8
# 27 ratings
# $199.99
# Fairchild Estate
# Sigaro Cabernet Sauvignon 2008
# United States
# ·
# Napa Valley
# 4.8
# 27 ratings
# $199.99
# El Molino
# Pinot Noir 2015
# United States
# ·
# Rutherford
# 4.8
# 26 ratings
# $75.99
# Mollydooker
# Velvet Glove Shiraz N.V.
# Australia
# ·
# McLaren Vale
# 4.7
# 1676 ratings
# $174.84
# Caymus
# Special Selection Cabernet Sauvignon 2015
# United States
# ·
# Napa Valley
# 4.7
# 2025 ratings
# $199.99
# Odette
# Estate Cabernet Sauvignon 2014
# United States
# ·
# Stags Leap District
# 4.7
# 682 ratings
# $169.99
# Viña Cobos
# Cobos Marchiori Vineyard Malbec 2013
# Argentina
# ·
# Mendoza
# 4.7
# 531 ratings
# $199.90
# Palmaz
# Cabernet Sauvignon 2015
# United States
# ·
# Napa Valley
# 4.7
# 219 ratings
# $165
# Inglenook
# Rubicon 2008
# United States
# ·
# Rutherford
# 4.7
# 171 ratings
# $179
# Cakebread
# Cabernet Sauvignon Benchland Select 2014
# United States
# ·
# Napa Valley
# 4.7
# 158 ratings
# $139.99
# Numanthia
# Termanthia 2007
# Spain
# ·
# Toro
# 4.7
# 155 ratings
# $189.99
# Mollydooker
# Velvet Glove Shiraz 2017
# Australia
# ·
# McLaren Vale
# 4.7
# 155 ratings
# $175.99
# Saxum
# James Berry Vineyard 2013
# United States
# ·
# Paso Robles
# 4.7
# 110 ratings
# $199.99
# Frias
# Prado N.V.
# United States
# ·
# Oakville
# 4.7
# 109 ratings
# $164.99
# Macauley
# Reserve Cabernet Sauvignon N.V.
# United States
# ·
# Napa Valley
# 4.7
# 95 ratings
# $164.99
# Hourglass
# Estate Cabernet Sauvignon 2012
# United States
# ·
# Napa Valley
# 4.7
# 86 ratings
# $199.99
# Checkerboard Vineyards
# Kings Row Red 2012
# United States
# ·
# Napa Valley
# 4.7
# 79 ratings
# $184.99

# %%
file_A=driver.find_element_by_class_name('explorerPage__results--3wqLw')
print(file_A.text)

# %%
def get_vivino_info(row):
    driver.get('https://www.vivino.com/explore?e=eJwdyjsKgDAURNHdTCkasZzOHYiViDxjDAETJQl-dq_Y3NNcH1kXDbwLVBW83FRlCf2w76C_tDhYwa48JTqTZcM-M0p2waZJThPFGuxcTNK48jB-849Cos4vingfEA==' + row['slug'])

    winery = driver.find_element_by_class_name("vintageTitle__winery--2YoIr>").text                                                                   
    wine = driver.find_element_by_class_name("vintageTitle__wine--U7t9G").text
    location = driver.find_element_by_class_name("vintageLocation__vintageLocation--1DF0p").text
    rating = driver.find_element_by_class_name("vivinoRatingWide__averageValue--1zL_5").text
    price = driver.find_element_by_class_name("<span class="">$75.99</span>").text

    return pd.Series({
        'winery': winery,
        'wine': wine,
        'location': location,
        'rating': rating,
        'price': price
    })

# %%
get_vivino_info(2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-06c9736f5515> in <module>
# ----> 1 get_vivino_info(2)
#
# <ipython-input-6-67ba87aff752> in get_vivino_info(row)
#       1 def get_vivino_info(row):
# ----> 2     driver.get('https://www.vivino.com/explore?e=eJwdyjsKgDAURNHdTCkasZzOHYiViDxjDAETJQl-dq_Y3NNcH1kXDbwLVBW83FRlCf2w76C_tDhYwa48JTqTZcM-M0p2waZJThPFGuxcTNK48jB-849Cos4vingfEA==' + row['slug'])
#       3
#       4     winery = driver.find_element_by_class_name("vintageTitle__winery--2YoIr>").text
#       5     wine = driver.find_element_by_class_name("vintageTitle__wine--U7t9G").text
#
# TypeError: 'int' object is not subscriptable

# %%
class Sel(unittest.TestCase):
    def setUp(self):
        self.driver = webdriver.chromedriver()
        self.driver.implicitly_wait(30)
        self.base_url = 'https://www.vivino.com/explore?e=eJwdyjsKgDAURNHdTCkasZzOHYiViDxjDAETJQl-dq_Y3NNcH1kXDbwLVBW83FRlCf2w76C_tDhYwa48JTqTZcM-M0p2waZJThPFGuxcTNK48jB-849Cos4vingfEA=='
        self.verificationErrors = []
        self.accept_next_alert = True
    def test_sel(self):
        driver = self.driver
        delay = 3
        driver.get(self.base_url + "/search?q=stackoverflow&src=typd")
        driver.find_element_by_link_text("All").click()
        for i in range(1,100):
            self.driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
            time.sleep(4)
        html_source = driver.page_source
        data = html_source.encode('utf-8')


if __name__ == "__main__":
    unittest.main()
